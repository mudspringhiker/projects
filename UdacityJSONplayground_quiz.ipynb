# %% [markdown]
# # Udacity: JSON Playground and Quiz
#
# To experiment with this code freely you will have to run this code locally.
# Take a look at the main() function for an example of how to use the code.
# We have provided example json output in the other code editor tabs for you to
# look at, but you will not be able to run any queries through our UI.

# %%
import json
import requests

# %%
BASE_URL = "http://musicbrainz.org/ws/2/"
ARTIST_URL = BASE_URL + "artist/"

# %% [markdown]
# Query parameters are given to the requests.get function as a dictionary; this variable contains some starter parameters.

# %%
query_type = {"simple": {},
              "atr": {"inc": "aliases+tags+ratings"},
              "aliases": {"inc": "aliases"},
              "releases": {"inc": "releases"}}

# %%
def query_site(url, params, uid="", fmt="json"):
    # This is the main function for making queries to the musicbrainz API.
    # A json document should be returned by the query.
    params["fmt"] = fmt
    r = requests.get(url + uid, params=params)
    print "requesting", r.url
    
    if r.status_code == requests.codes.ok:
        return r.json()
    else:
        r.raise_for_status()

# %%
def query_by_name(url, params, name):
    # This adds an artist name to the query parameters before making an
    # API call to the function above.
    params["query"] = "artist:" + name
    return query_site(url, params)

# %%
def pretty_print(data, indent=4):
    # After we get our input, we can format it to be more readable
    # by using this function.
    if type(data) == dict:
        print json.dumps(data, indent=indent, sort_keys=True)
    else:
        print data

# %% [markdown]
# Copy of rest of code for the JSON playground
#
# def main():
#     '''
#     Modify the function calls and indexing below to answer the questions on
#     the next quiz. HINT: Note how the output we get from the site is a
#     multi-level JSON document, so try making print statements to step through
#     the structure one level at a time or copy the output to a separate output
#     file.
#     '''
#     results = query_by_name(ARTIST_URL, query_type["simple"], "Nirvana")
#     pretty_print(results)
#
#     artist_id = results["artists"][1]["id"]
#     print "\nARTIST:"
#     pretty_print(results["artists"][1])
#
#     artist_data = query_site(ARTIST_URL, query_type["releases"], artist_id)
#     releases = artist_data["releases"]
#     print "\nONE RELEASE:"
#     pretty_print(releases[0], indent=2)
#     release_titles = [r["title"] for r in releases]
#
#     print "\nALL TITLES:"
#     for t in release_titles:
#         print t
#
#
# if __name__ == '__main__':
#     main()

# %% [markdown]
# #### Lil Wayne

# %%
lilwayne = query_by_name(ARTIST_URL, query_type["simple"], "Lil Wayne")
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3ALil+Wayne&fmt=json

# %%
lilwayne
# Out:
# {u'artists': [{u'aliases': [{u'begin-date': None,
#      u'end-date': None,
#      u'locale': None,
#      u'name': u"Lil' Wayne",
#      u'primary': None,
#      u'sort-name': u"Lil' Wayne",
#      u'type': None}],
#    u'area': {u'id': u'26b70c12-9676-41b4-a7e7-bc3d4dd80f65',
#     u'name': u'Miami Beach',
#     u'sort-name': u'Miami Beach'},
#    u'begin-area': {u'id': u'3c5a0506-d852-4e96-8d1e-d8126328f3be',
#     u'name': u'New Orleans',
#     u'sort-name': u'New Orleans'},
#    u'disambiguation': u'American rapper',
#    u'gender': u'male',
#    u'id': u'ac9a487a-d9d2-4f27-bb23-0f4686488345',
#    u'life-span': {u'begin': u'1982-09-27', u'ended': None},
#    u'name': u'Lil Wayne',
#    u'score': u'100',
#    u'sort-name': u'Lil Wayne',
#    u'tags': [{u'count': 1, u'name': u'rap'},
#     {u'count': 1, u'name': u'hip hop'},
#     {u'count': 2, u'name': u'southern hip hop'},
#     {u'count': 2, u'name': u'gangsta rap'},
#     {u'count': 1, u'name': u'pop rap'},
#     {u'count': 1, u'name': u'rap rock'},
#     {u'count': 0, u'name': u'hip hop rnb and dance hall'},
#     {u'count': 1, u'name': u'chopped and screwed'},
#     {u'count': 0, u'name': u'lil wayne'},
#     {u'count': 1, u'name': u'r&b'},
#     {u'count': 1, u'name': u'contemporary r&b'}],
#    u'type': u'Person'},
#   {u'disambiguation': u'Rock band from Birmingham, AL fronted by Rodney Reaves',
#    u'id': u'063133fd-380d-4493-b4d1-bdd4dbeb3506',
#    u'life-span': {u'begin': u'1997', u'ended': None},
#    u'name': u'Wayne',
#    u'score': u'58',
#    u'sort-name': u'Wayne',
#    u'type': u'Group'},
#   {u'disambiguation': u'"An ex-hobo troubadour, now...at the Incorrectional Facility"',
#    u'id': u'8806228e-1254-48b6-896a-28831476c1bf',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne',
#    u'score': u'58',
#    u'sort-name': u'Wayne',
#    u'type': u'Person'},
#   {u'disambiguation': u'Band created by former Metal Church singer David Wayne',
#    u'id': u'e48bc42a-88f1-4a47-8718-02cdef131f93',
#    u'life-span': {u'begin': u'2001', u'end': u'2005', u'ended': True},
#    u'name': u'Wayne',
#    u'score': u'58',
#    u'sort-name': u'Wayne',
#    u'type': u'Group'},
#   {u'disambiguation': u'Muppet character',
#    u'id': u'00e2990f-f3df-49be-bc30-92e3b5114bd1',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne',
#    u'score': u'58',
#    u'sort-name': u'Wayne',
#    u'tags': [{u'count': 1, u'name': u'muppet character'}],
#    u'type': u'Character'},
#   {u'disambiguation': u'Probably Bay Area Rapper',
#    u'id': u'f339510e-739a-4063-84e1-034a69b5fb47',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne',
#    u'score': u'58',
#    u'sort-name': u'Wayne'},
#   {u'disambiguation': u'of the Rude Boys',
#    u'gender': u'male',
#    u'id': u'563500d8-bbd5-4f28-a623-c46ac0ef5792',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne',
#    u'score': u'48',
#    u'sort-name': u'Wayne',
#    u'type': u'Person'},
#   {u'gender': u'male',
#    u'id': u'e2c4bf85-748b-42fe-bef0-63cbbc1baa68',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne Wayne',
#    u'score': u'46',
#    u'sort-name': u'Wayne, Wayne',
#    u'type': u'Person'},
#   {u'aliases': [{u'begin-date': None,
#      u'end-date': None,
#      u'locale': None,
#      u'name': u'Wayne Shoter',
#      u'primary': None,
#      u'sort-name': u'Wayne Shoter',
#      u'type': None}],
#    u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'begin-area': {u'id': u'85c7cd5f-6fe2-4195-a44d-69fa390bd6ec',
#     u'name': u'Newark',
#     u'sort-name': u'Newark'},
#    u'country': u'US',
#    u'disambiguation': u'US jazz saxophonist and composer',
#    u'gender': u'male',
#    u'id': u'2379937f-6e0d-46a2-b8ff-633fafd72002',
#    u'ipis': [u'00028587650'],
#    u'life-span': {u'begin': u'1933-08-25', u'ended': None},
#    u'name': u'Wayne Shorter',
#    u'score': u'38',
#    u'sort-name': u'Shorter, Wayne',
#    u'tags': [{u'count': 1, u'name': u'jazz'},
#     {u'count': 1, u'name': u'american'},
#     {u'count': 1, u'name': u'jazz fusion'},
#     {u'count': 1, u'name': u'crossover jazz'},
#     {u'count': 1, u'name': u'progressive jazz'},
#     {u'count': 1, u'name': u'post-bop'},
#     {u'count': 1, u'name': u'hard bop'},
#     {u'count': 1, u'name': u'modal jazz'},
#     {u'count': 1, u'name': u'jazz and blues'}],
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'gender': u'male',
#    u'id': u'b6b6f1cf-e1c8-46e9-bc54-1a63ed1f8d51',
#    u'life-span': {u'begin': u'1942-04-03', u'ended': None},
#    u'name': u'Wayne Newton',
#    u'score': u'38',
#    u'sort-name': u'Newton, Wayne',
#    u'tags': [{u'count': 1, u'name': u'american'},
#     {u'count': 1, u'name': u'singer'}],
#    u'type': u'Person'},
#   {u'aliases': [{u'begin-date': None,
#      u'end-date': None,
#      u'locale': None,
#      u'name': u'Jan Christiansen',
#      u'primary': None,
#      u'sort-name': u'Jan Christiansen',
#      u'type': None},
#     {u'begin-date': None,
#      u'end-date': None,
#      u'locale': None,
#      u'name': u'Jan Wyne',
#      u'primary': None,
#      u'sort-name': u'Jan Wyne',
#      u'type': u'Search hint'}],
#    u'area': {u'id': u'85752fda-13c4-31a3-bee5-0e5cb1f51dad',
#     u'name': u'Germany',
#     u'sort-name': u'Germany'},
#    u'country': u'DE',
#    u'gender': u'male',
#    u'id': u'0f7f7e94-ce9d-496a-b894-42d642b5229e',
#    u'life-span': {u'begin': u'1974-01-11', u'ended': None},
#    u'name': u'Jan Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Jan',
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'disambiguation': u'US actor',
#    u'gender': u'male',
#    u'id': u'ed0076ca-cc35-4ea4-86ad-efaf4afcb4dc',
#    u'life-span': {u'begin': u'1907-05-26',
#     u'end': u'1979-06-11',
#     u'ended': True},
#    u'name': u'John Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, John',
#    u'tags': [{u'count': 1, u'name': u'actor'}],
#    u'type': u'Person'},
#   {u'id': u'cba2dbe3-7e0f-4dc8-84f8-78707e81e9d7',
#    u'life-span': {u'ended': None},
#    u'name': u'Chris Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Chris',
#    u'tags': [{u'count': 1, u'name': u'reggae'}],
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'gender': u'male',
#    u'id': u'c0fa7585-7db1-410f-b59f-af953380b124',
#    u'life-span': {u'begin': u'1940-07-22',
#     u'end': u'1971-08-15',
#     u'ended': True},
#    u'name': u'Thomas Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Thomas',
#    u'tags': [{u'count': 0, u'name': u'death by automobile'}],
#    u'type': u'Person'},
#   {u'area': {u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#     u'name': u'United Kingdom',
#     u'sort-name': u'United Kingdom'},
#    u'begin-area': {u'id': u'226c4dca-ef2a-4d4b-ba25-4118d116557a',
#     u'name': u'Birmingham',
#     u'sort-name': u'Birmingham'},
#    u'country': u'GB',
#    u'end-area': {u'id': u'226c4dca-ef2a-4d4b-ba25-4118d116557a',
#     u'name': u'Birmingham',
#     u'sort-name': u'Birmingham'},
#    u'gender': u'male',
#    u'id': u'76907faf-f81e-45c2-b5ae-4dd92a0802f7',
#    u'life-span': {u'begin': u'1943-08-18',
#     u'end': u'2004-08-31',
#     u'ended': True},
#    u'name': u'Carl Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Carl',
#    u'type': u'Person'},
#   {u'aliases': [{u'begin-date': None,
#      u'end-date': None,
#      u'locale': None,
#      u'name': u'Wayne Jarett',
#      u'primary': None,
#      u'sort-name': u'Wayne Jarett',
#      u'type': None}],
#    u'area': {u'id': u'2dd47a64-91d5-3b13-bc94-80043ed063d7',
#     u'name': u'Jamaica',
#     u'sort-name': u'Jamaica'},
#    u'begin-area': {u'id': u'23e0d135-9fe7-48cb-b2c4-93addd3d1e37',
#     u'name': u'Kingston',
#     u'sort-name': u'Kingston'},
#    u'country': u'JM',
#    u'gender': u'male',
#    u'id': u'fedbb26f-9d3f-4094-8fee-38734bef81da',
#    u'life-span': {u'begin': u'1956', u'ended': None},
#    u'name': u'Wayne Jarrett',
#    u'score': u'38',
#    u'sort-name': u'Jarrett, Wayne',
#    u'type': u'Person'},
#   {u'aliases': [{u'begin-date': None,
#      u'end-date': None,
#      u'locale': None,
#      u'name': u'Wayne G Presents Twisted',
#      u'primary': None,
#      u'sort-name': u'Wayne G Presents Twisted',
#      u'type': None}],
#    u'area': {u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed',
#     u'name': u'United Kingdom',
#     u'sort-name': u'United Kingdom'},
#    u'country': u'GB',
#    u'gender': u'male',
#    u'id': u'7920de2d-768e-44d8-8a8f-dcdc0f4afd90',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne G',
#    u'score': u'38',
#    u'sort-name': u'Wayne G',
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'begin-area': {u'id': u'6dd9c4ba-9548-4a74-ab19-3d62e14be360',
#     u'name': u'Kings Mountain',
#     u'sort-name': u'Kings Mountain'},
#    u'country': u'US',
#    u'gender': u'male',
#    u'id': u'5cf7e696-3c52-4021-866c-7ce71ab8671a',
#    u'life-span': {u'begin': u'1972-10-23', u'ended': None},
#    u'name': u'Jimmy Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Jimmy',
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'gender': u'male',
#    u'id': u'9a65e3a2-b905-49d1-beca-d3872a57504d',
#    u'life-span': {u'begin': u'1956-07-26', u'ended': None},
#    u'name': u'Wayne Krantz',
#    u'score': u'38',
#    u'sort-name': u'Krantz, Wayne',
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'gender': u'male',
#    u'id': u'5faeca1e-3f0d-4364-9428-faa9a855a246',
#    u'life-span': {u'begin': u'1921', u'ended': None},
#    u'name': u'Jerry Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Jerry',
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'gender': u'male',
#    u'id': u'03eacebb-a3ab-4a45-bf64-abc63960346e',
#    u'life-span': {u'ended': None},
#    u'name': u'Dallas Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Dallas',
#    u'type': u'Person'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'gender': u'female',
#    u'id': u'bb3f5a55-0e2c-4a33-9e79-b14a923fa97b',
#    u'life-span': {u'begin': u'1924-08-26',
#     u'end': u'1978-02-06',
#     u'ended': True},
#    u'name': u'Frances Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Frances',
#    u'type': u'Person'},
#   {u'id': u'08b6650c-b8fd-4c88-aa85-d6ff6fc5c27d',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne Brasel',
#    u'score': u'38',
#    u'sort-name': u'Brasel, Wayne'},
#   {u'area': {u'id': u'489ce91b-6658-3307-9877-795b68554c98',
#     u'name': u'United States',
#     u'sort-name': u'United States'},
#    u'country': u'US',
#    u'gender': u'male',
#    u'id': u'ae1e64a3-2032-4271-a283-a022b4f94467',
#    u'life-span': {u'begin': u'1937-12-31', u'ended': None},
#    u'name': u'Alvis Wayne',
#    u'score': u'38',
#    u'sort-name': u'Wayne, Alvis',
#    u'type': u'Person'},
#   {u'aliases': [{u'begin-date': None,
#      u'end-date': None,
#      u'locale': None,
#      u'name': u'Wayne "Ambassador Of House" Williams',
#      u'primary': None,
#      u'sort-name': u'Wayne "Ambassador Of House" Williams',
#      u'type': None}],
#    u'id': u'113b7b5f-dacb-4530-a723-fefa4a087d68',
#    u'life-span': {u'ended': None},
#    u'name': u'Wayne Williams',
#    u'score': u'38',
#    u'sort-name': u'Williams, Wayne',
#    u'type': u'Person'}],
#  u'count': 1380,
#  u'created': u'2016-08-23T13:46:09.669Z',
#  u'offset': 0}

# %%
pretty_print(lilwayne)
# Out:
# {
#     "artists": [
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Lil' Wayne",
#                     "primary": null,
#                     "sort-name": "Lil' Wayne",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "26b70c12-9676-41b4-a7e7-bc3d4dd80f65",
#                 "name": "Miami Beach",
#                 "sort-name": "Miami Beach"
#             },
#             "begin-area": {
#                 "id": "3c5a0506-d852-4e96-8d1e-d8126328f3be",
#                 "name": "New Orleans",
#                 "sort-name": "New Orleans"
#             },
#             "disambiguation": "American rapper",
#             "gender": "male",
#             "id": "ac9a487a-d9d2-4f27-bb23-0f4686488345",
#             "life-span": {
#                 "begin": "1982-09-27",
#                 "ended": null
#             },
#             "name": "Lil Wayne",
#             "score": "100",
#             "sort-name": "Lil Wayne",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "rap"
#                 },
#                 {
#                     "count": 1,
#                     "name": "hip hop"
#                 },
#                 {
#                     "count": 2,
#                     "name": "southern hip hop"
#                 },
#                 {
#                     "count": 2,
#                     "name": "gangsta rap"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop rap"
#                 },
#                 {
#                     "count": 1,
#                     "name": "rap rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "hip hop rnb and dance hall"
#                 },
#                 {
#                     "count": 1,
#                     "name": "chopped and screwed"
#                 },
#                 {
#                     "count": 0,
#                     "name": "lil wayne"
#                 },
#                 {
#                     "count": 1,
#                     "name": "r&b"
#                 },
#                 {
#                     "count": 1,
#                     "name": "contemporary r&b"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "disambiguation": "Rock band from Birmingham, AL fronted by Rodney Reaves",
#             "id": "063133fd-380d-4493-b4d1-bdd4dbeb3506",
#             "life-span": {
#                 "begin": "1997",
#                 "ended": null
#             },
#             "name": "Wayne",
#             "score": "58",
#             "sort-name": "Wayne",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "\"An ex-hobo troubadour, now...at the Incorrectional Facility\"",
#             "id": "8806228e-1254-48b6-896a-28831476c1bf",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne",
#             "score": "58",
#             "sort-name": "Wayne",
#             "type": "Person"
#         },
#         {
#             "disambiguation": "Band created by former Metal Church singer David Wayne",
#             "id": "e48bc42a-88f1-4a47-8718-02cdef131f93",
#             "life-span": {
#                 "begin": "2001",
#                 "end": "2005",
#                 "ended": true
#             },
#             "name": "Wayne",
#             "score": "58",
#             "sort-name": "Wayne",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "Muppet character",
#             "id": "00e2990f-f3df-49be-bc30-92e3b5114bd1",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne",
#             "score": "58",
#             "sort-name": "Wayne",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "muppet character"
#                 }
#             ],
#             "type": "Character"
#         },
#         {
#             "disambiguation": "Probably Bay Area Rapper",
#             "id": "f339510e-739a-4063-84e1-034a69b5fb47",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne",
#             "score": "58",
#             "sort-name": "Wayne"
#         },
#         {
#             "disambiguation": "of the Rude Boys",
#             "gender": "male",
#             "id": "563500d8-bbd5-4f28-a623-c46ac0ef5792",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne",
#             "score": "48",
#             "sort-name": "Wayne",
#             "type": "Person"
#         },
#         {
#             "gender": "male",
#             "id": "e2c4bf85-748b-42fe-bef0-63cbbc1baa68",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne Wayne",
#             "score": "46",
#             "sort-name": "Wayne, Wayne",
#             "type": "Person"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Wayne Shoter",
#                     "primary": null,
#                     "sort-name": "Wayne Shoter",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "85c7cd5f-6fe2-4195-a44d-69fa390bd6ec",
#                 "name": "Newark",
#                 "sort-name": "Newark"
#             },
#             "country": "US",
#             "disambiguation": "US jazz saxophonist and composer",
#             "gender": "male",
#             "id": "2379937f-6e0d-46a2-b8ff-633fafd72002",
#             "ipis": [
#                 "00028587650"
#             ],
#             "life-span": {
#                 "begin": "1933-08-25",
#                 "ended": null
#             },
#             "name": "Wayne Shorter",
#             "score": "38",
#             "sort-name": "Shorter, Wayne",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "jazz"
#                 },
#                 {
#                     "count": 1,
#                     "name": "american"
#                 },
#                 {
#                     "count": 1,
#                     "name": "jazz fusion"
#                 },
#                 {
#                     "count": 1,
#                     "name": "crossover jazz"
#                 },
#                 {
#                     "count": 1,
#                     "name": "progressive jazz"
#                 },
#                 {
#                     "count": 1,
#                     "name": "post-bop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "hard bop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "modal jazz"
#                 },
#                 {
#                     "count": 1,
#                     "name": "jazz and blues"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "male",
#             "id": "b6b6f1cf-e1c8-46e9-bc54-1a63ed1f8d51",
#             "life-span": {
#                 "begin": "1942-04-03",
#                 "ended": null
#             },
#             "name": "Wayne Newton",
#             "score": "38",
#             "sort-name": "Newton, Wayne",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "american"
#                 },
#                 {
#                     "count": 1,
#                     "name": "singer"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Jan Christiansen",
#                     "primary": null,
#                     "sort-name": "Jan Christiansen",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Jan Wyne",
#                     "primary": null,
#                     "sort-name": "Jan Wyne",
#                     "type": "Search hint"
#                 }
#             ],
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "gender": "male",
#             "id": "0f7f7e94-ce9d-496a-b894-42d642b5229e",
#             "life-span": {
#                 "begin": "1974-01-11",
#                 "ended": null
#             },
#             "name": "Jan Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Jan",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "disambiguation": "US actor",
#             "gender": "male",
#             "id": "ed0076ca-cc35-4ea4-86ad-efaf4afcb4dc",
#             "life-span": {
#                 "begin": "1907-05-26",
#                 "end": "1979-06-11",
#                 "ended": true
#             },
#             "name": "John Wayne",
#             "score": "38",
#             "sort-name": "Wayne, John",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "actor"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "id": "cba2dbe3-7e0f-4dc8-84f8-78707e81e9d7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Chris Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Chris",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "reggae"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "male",
#             "id": "c0fa7585-7db1-410f-b59f-af953380b124",
#             "life-span": {
#                 "begin": "1940-07-22",
#                 "end": "1971-08-15",
#                 "ended": true
#             },
#             "name": "Thomas Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Thomas",
#             "tags": [
#                 {
#                     "count": 0,
#                     "name": "death by automobile"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "226c4dca-ef2a-4d4b-ba25-4118d116557a",
#                 "name": "Birmingham",
#                 "sort-name": "Birmingham"
#             },
#             "country": "GB",
#             "end-area": {
#                 "id": "226c4dca-ef2a-4d4b-ba25-4118d116557a",
#                 "name": "Birmingham",
#                 "sort-name": "Birmingham"
#             },
#             "gender": "male",
#             "id": "76907faf-f81e-45c2-b5ae-4dd92a0802f7",
#             "life-span": {
#                 "begin": "1943-08-18",
#                 "end": "2004-08-31",
#                 "ended": true
#             },
#             "name": "Carl Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Carl",
#             "type": "Person"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Wayne Jarett",
#                     "primary": null,
#                     "sort-name": "Wayne Jarett",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "2dd47a64-91d5-3b13-bc94-80043ed063d7",
#                 "name": "Jamaica",
#                 "sort-name": "Jamaica"
#             },
#             "begin-area": {
#                 "id": "23e0d135-9fe7-48cb-b2c4-93addd3d1e37",
#                 "name": "Kingston",
#                 "sort-name": "Kingston"
#             },
#             "country": "JM",
#             "gender": "male",
#             "id": "fedbb26f-9d3f-4094-8fee-38734bef81da",
#             "life-span": {
#                 "begin": "1956",
#                 "ended": null
#             },
#             "name": "Wayne Jarrett",
#             "score": "38",
#             "sort-name": "Jarrett, Wayne",
#             "type": "Person"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Wayne G Presents Twisted",
#                     "primary": null,
#                     "sort-name": "Wayne G Presents Twisted",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "gender": "male",
#             "id": "7920de2d-768e-44d8-8a8f-dcdc0f4afd90",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne G",
#             "score": "38",
#             "sort-name": "Wayne G",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "6dd9c4ba-9548-4a74-ab19-3d62e14be360",
#                 "name": "Kings Mountain",
#                 "sort-name": "Kings Mountain"
#             },
#             "country": "US",
#             "gender": "male",
#             "id": "5cf7e696-3c52-4021-866c-7ce71ab8671a",
#             "life-span": {
#                 "begin": "1972-10-23",
#                 "ended": null
#             },
#             "name": "Jimmy Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Jimmy",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "male",
#             "id": "9a65e3a2-b905-49d1-beca-d3872a57504d",
#             "life-span": {
#                 "begin": "1956-07-26",
#                 "ended": null
#             },
#             "name": "Wayne Krantz",
#             "score": "38",
#             "sort-name": "Krantz, Wayne",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "male",
#             "id": "5faeca1e-3f0d-4364-9428-faa9a855a246",
#             "life-span": {
#                 "begin": "1921",
#                 "ended": null
#             },
#             "name": "Jerry Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Jerry",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "male",
#             "id": "03eacebb-a3ab-4a45-bf64-abc63960346e",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Dallas Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Dallas",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "bb3f5a55-0e2c-4a33-9e79-b14a923fa97b",
#             "life-span": {
#                 "begin": "1924-08-26",
#                 "end": "1978-02-06",
#                 "ended": true
#             },
#             "name": "Frances Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Frances",
#             "type": "Person"
#         },
#         {
#             "id": "08b6650c-b8fd-4c88-aa85-d6ff6fc5c27d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne Brasel",
#             "score": "38",
#             "sort-name": "Brasel, Wayne"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "male",
#             "id": "ae1e64a3-2032-4271-a283-a022b4f94467",
#             "life-span": {
#                 "begin": "1937-12-31",
#                 "ended": null
#             },
#             "name": "Alvis Wayne",
#             "score": "38",
#             "sort-name": "Wayne, Alvis",
#             "type": "Person"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Wayne \"Ambassador Of House\" Williams",
#                     "primary": null,
#                     "sort-name": "Wayne \"Ambassador Of House\" Williams",
#                     "type": null
#                 }
#             ],
#             "id": "113b7b5f-dacb-4530-a723-fefa4a087d68",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Wayne Williams",
#             "score": "38",
#             "sort-name": "Williams, Wayne",
#             "type": "Person"
#         }
#     ],
#     "count": 1380,
#     "created": "2016-08-23T13:46:09.669Z",
#     "offset": 0
# }

# %%
lilwayne_id = lilwayne["artists"][0]["id"]

# %%
lilwayne_id
# Out:
# u'ac9a487a-d9d2-4f27-bb23-0f4686488345'

# %%
pretty_print(lilwayne["artists"][0])
# Out:
# {
#     "aliases": [
#         {
#             "begin-date": null,
#             "end-date": null,
#             "locale": null,
#             "name": "Lil' Wayne",
#             "primary": null,
#             "sort-name": "Lil' Wayne",
#             "type": null
#         }
#     ],
#     "area": {
#         "id": "26b70c12-9676-41b4-a7e7-bc3d4dd80f65",
#         "name": "Miami Beach",
#         "sort-name": "Miami Beach"
#     },
#     "begin-area": {
#         "id": "3c5a0506-d852-4e96-8d1e-d8126328f3be",
#         "name": "New Orleans",
#         "sort-name": "New Orleans"
#     },
#     "disambiguation": "American rapper",
#     "gender": "male",
#     "id": "ac9a487a-d9d2-4f27-bb23-0f4686488345",
#     "life-span": {
#         "begin": "1982-09-27",
#         "ended": null
#     },
#     "name": "Lil Wayne",
#     "score": "100",
#     "sort-name": "Lil Wayne",
#     "tags": [
#         {
#             "count": 1,
#             "name": "rap"
#         },
#         {
#             "count": 1,
#             "name": "hip hop"
#         },
#         {
#             "count": 2,
#             "name": "southern hip hop"
#         },
#         {
#             "count": 2,
#             "name": "gangsta rap"
#         },
#         {
#             "count": 1,
#             "name": "pop rap"
#         },
#         {
#             "count": 1,
#             "name": "rap rock"
#         },
#         {
#             "count": 0,
#             "name": "hip hop rnb and dance hall"
#         },
#         {
#             "count": 1,
#             "name": "chopped and screwed"
#         },
#         {
#             "count": 0,
#             "name": "lil wayne"
#         },
#         {
#             "count": 1,
#             "name": "r&b"
#         },
#         {
#             "count": 1,
#             "name": "contemporary r&b"
#         }
#     ],
#     "type": "Person"
# }

# %%
lilwayne_data = query_site(ARTIST_URL, query_type["releases"], lilwayne_id)
# Out:
# requesting http://musicbrainz.org/ws/2/artist/ac9a487a-d9d2-4f27-bb23-0f4686488345?fmt=json&inc=releases

# %%
lilwayne_releases = lilwayne_data["releases"]

# %%
pretty_print(lilwayne_releases[0], indent=2)
# Out:
# {
#   "barcode": null,
#   "country": "GB",
#   "date": "2005-02-07",
#   "disambiguation": "",
#   "id": "153134af-fdb8-4728-a0ee-93a490bcb1fb",
#   "packaging": null,
#   "packaging-id": null,
#   "quality": "normal",
#   "release-events": [
#     {
#       "area": {
#         "disambiguation": "",
#         "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#         "iso-3166-1-codes": [
#           "GB"
#         ],
#         "name": "United Kingdom",
#         "sort-name": "United Kingdom"
#       },
#       "date": "2005-02-07"
#     }
#   ],
#   "status": "Official",
#   "status-id": "4e304316-386d-3409-af2e-78857eec5cfe",
#   "text-representation": {
#     "language": "eng",
#     "script": "Latn"
#   },
#   "title": "Soldier"
# }

# %%
lilwayne_release_titles = [lwr["title"] for lwr in lilwayne_releases]
for title in lilwayne_release_titles:
    print title
# Out:
# Soldier
# Tha Carter II
# Tha Carter
# Da Drought
# SQ6
# Lights Out
# 500 Degreez
# Tha Carter II: Chopped & Screwed
# Gimme That (remix)
# Tha Carter II
# The Suffix: Remastered
# Hustler Musik
# Tha Carter II
# Like Father, Like Son
# Tha Carter
# Like Father, Like Son
# Da Drought 2
# The Prefix
# Soldier
# Tha Carter II
# The W. Carter Collection 2
# Soldier
# Neva Get Enuf
# Tha Block Is Hot
# SQ4

# %% [markdown]
# #### Quiz:
#
# How many bands names "First Aid Kit"?

# %%
firstaidkit = query_by_name(ARTIST_URL, query_type["simple"], "First Aid Kit")
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3AFirst+Aid+Kit&fmt=json

# %%
pretty_print(firstaidkit, indent=4)
# Out:
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "23d10872-f5ae-3f0c-bf55-332788a16ecb",
#                 "name": "Sweden",
#                 "sort-name": "Sweden"
#             },
#             "begin-area": {
#                 "id": "1127ddc2-eab3-4662-8718-6adbdeea3b10",
#                 "name": "Stockholm",
#                 "sort-name": "Stockholm"
#             },
#             "country": "SE",
#             "disambiguation": "Swedish folk band",
#             "id": "373faa02-74d7-4b1d-9b47-7574ad510f8d",
#             "life-span": {
#                 "begin": "2007",
#                 "ended": null
#             },
#             "name": "First Aid Kit",
#             "score": "100",
#             "sort-name": "First Aid Kit",
#             "tags": [
#                 {
#                     "count": 0,
#                     "name": "remember"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "471c46a7-afc5-31c4-923c-d0444f5053a4",
#                 "name": "Spain",
#                 "sort-name": "Spain"
#             },
#             "begin-area": {
#                 "id": "12c3b82e-fcab-4219-9bd5-792089d8280e",
#                 "name": "Barcelona",
#                 "sort-name": "Barcelona"
#             },
#             "country": "ES",
#             "disambiguation": "Spanish indie electronic band",
#             "id": "e4466078-fb0f-4899-98a2-7c7dfeb14714",
#             "life-span": {
#                 "begin": "2004",
#                 "ended": null
#             },
#             "name": "First Aid Kit",
#             "score": "100",
#             "sort-name": "First Aid Kit",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "ko",
#                     "name": "\uc5d0\uc774\ub4dc",
#                     "primary": null,
#                     "sort-name": "\uc5d0\uc774\ub4dc",
#                     "type": "Artist name"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "en",
#                     "name": "AID",
#                     "primary": null,
#                     "sort-name": "AID",
#                     "type": "Artist name"
#                 }
#             ],
#             "area": {
#                 "id": "b9f7d640-46e8-313e-b158-ded6d18593b3",
#                 "name": "South Korea",
#                 "sort-name": "South Korea"
#             },
#             "country": "KR",
#             "disambiguation": "Korean producer",
#             "gender": "male",
#             "id": "3266ea60-5690-464a-ae67-27c8681a9723",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "FIRST AID",
#             "score": "50",
#             "sort-name": "FIRST AID",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "1f1fc3a4-9500-39b8-9f10-f0a465557eef",
#                 "name": "Russia",
#                 "sort-name": "Russia"
#             },
#             "country": "RU",
#             "disambiguation": "Russian metal",
#             "id": "5bb6d8b6-dcd8-46e0-84dc-5a0d927c8475",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "e1c1215f-dcc0-35b4-b840-d2ca2151593b",
#                 "name": "Estonia",
#                 "sort-name": "Estonia"
#             },
#             "country": "EE",
#             "disambiguation": "Estonian band",
#             "id": "93d871dc-38f4-442e-8292-db7d670794ea",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "caac77d1-a5c8-3e6e-8e27-90b44dcc1446",
#                 "name": "Austria",
#                 "sort-name": "Austria"
#             },
#             "begin-area": {
#                 "id": "caac77d1-a5c8-3e6e-8e27-90b44dcc1446",
#                 "name": "Austria",
#                 "sort-name": "Austria"
#             },
#             "country": "AT",
#             "disambiguation": "Austrian Rockband",
#             "id": "268d84a6-620a-4a87-b467-d2236f9264b6",
#             "life-span": {
#                 "begin": "2000",
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "featured on \u201cStay the Night\u201d by Kuts & Mouse",
#             "id": "3dae6add-712f-4592-8ece-da15d02ec943",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "48",
#             "sort-name": "First Aid"
#         },
#         {
#             "id": "c3eee377-bfd1-49fa-906c-7562db86a45d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The First Aid",
#             "score": "38",
#             "sort-name": "First Aid, The",
#             "type": "Group"
#         },
#         {
#             "id": "612e0dcb-2b47-4feb-ad34-6259433de61d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid 4 Souls",
#             "score": "38",
#             "sort-name": "First Aid 4 Souls"
#         },
#         {
#             "id": "fbf39528-f7a1-491d-a5d4-94df61f88ad9",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "DJ First Aid",
#             "score": "38",
#             "sort-name": "DJ First Aid"
#         },
#         {
#             "disambiguation": "Germany",
#             "id": "97b182ff-5f86-451c-b2b4-27840b7d512a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "First Aid",
#             "score": "35",
#             "sort-name": "First Aid"
#         },
#         {
#             "id": "ae609ba9-5df4-4ef4-aa4a-18805397ef24",
#             "life-span": {
#                 "begin": "1990",
#                 "ended": null
#             },
#             "name": "A\u00edd",
#             "score": "31",
#             "sort-name": "A\u00edd",
#             "type": "Person"
#         },
#         {
#             "id": "ed6459f1-257f-433a-85c1-970b2fbbc0af",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "K.I.T.",
#             "score": "27",
#             "sort-name": "K.I.T."
#         },
#         {
#             "disambiguation": "song \"Piss die Wand an\" feat. Officer Bronco & Brad Pitch",
#             "id": "2b1895a9-6906-4700-b0ed-98561cb58474",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Kit",
#             "score": "27",
#             "sort-name": "Kit",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "08310658-51eb-3801-80de-5a0739207115",
#                 "name": "France",
#                 "sort-name": "France"
#             },
#             "country": "FR",
#             "disambiguation": "Paris electro-pop trio",
#             "id": "2d1caf76-ccd5-4cbc-a1b0-c36186c81c15",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "KIT",
#             "score": "27",
#             "sort-name": "KIT",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "40d758a4-b7c2-40f3-b439-5efbd2a3b038",
#                 "name": "Bristol",
#                 "sort-name": "Bristol"
#             },
#             "disambiguation": "Kit Fegradoe - UK ambient/electronic artist",
#             "gender": "male",
#             "id": "b199b386-e0b1-4137-9faa-c9bc09b1eda4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Kit",
#             "score": "27",
#             "sort-name": "Kit",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "c998ef9b-8656-45f3-ba70-8d8c15a33a29",
#                 "name": "A\u00e7ores",
#                 "sort-name": "A\u00e7ores"
#             },
#             "disambiguation": "Jo\u00e3o Martins, Azorean artist",
#             "gender": "male",
#             "id": "a710d032-28fd-4657-9ae7-3f2a7a53a94f",
#             "life-span": {
#                 "end": "2016-02",
#                 "ended": true
#             },
#             "name": "Kit",
#             "score": "27",
#             "sort-name": "Kit",
#             "type": "Person"
#         },
#         {
#             "disambiguation": "George Chen, Vice Cooler",
#             "id": "ede72177-00cd-4ddf-b04b-1b7c754fed79",
#             "life-span": {
#                 "begin": "2003",
#                 "ended": null
#             },
#             "name": "KIT",
#             "score": "26",
#             "sort-name": "KIT",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Ferry Aid (Zeebrugge)",
#                     "primary": null,
#                     "sort-name": "Ferry Aid (Zeebrugge)",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "id": "590233d0-5ab2-4a67-8f43-a647c2100bdc",
#             "life-span": {
#                 "begin": "1987",
#                 "end": "1987",
#                 "ended": true
#             },
#             "name": "Ferry Aid",
#             "score": "20",
#             "sort-name": "Ferry Aid",
#             "type": "Group"
#         },
#         {
#             "id": "0ecaa896-58fa-4dca-b53d-8da7bc5f59c5",
#             "life-span": {
#                 "begin": "1984",
#                 "ended": null
#             },
#             "name": "Band Aid",
#             "score": "19",
#             "sort-name": "Band Aid",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "british"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "id": "d74731bd-79aa-4452-876d-b25d5c78b0b2",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Quench Aid",
#             "score": "19",
#             "sort-name": "Quench Aid"
#         },
#         {
#             "id": "d31ee795-51b3-4213-81ff-ea521f988d28",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Hearin Aid",
#             "score": "19",
#             "sort-name": "Hearin Aid"
#         },
#         {
#             "id": "375093c9-b20a-4955-80d1-e84fbacf4a6b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Kool Aid",
#             "score": "19",
#             "sort-name": "Kool Aid"
#         },
#         {
#             "area": {
#                 "id": "71bbafaa-e825-3e15-8ca9-017dcad1748b",
#                 "name": "Canada",
#                 "sort-name": "Canada"
#             },
#             "begin-area": {
#                 "id": "6ccc62d1-bdd8-4f08-8fae-bfaa5310e5ef",
#                 "name": "Vancouver",
#                 "sort-name": "Vancouver"
#             },
#             "country": "CA",
#             "id": "d2559845-4898-458e-aacf-6392ef92dc19",
#             "life-span": {
#                 "begin": "2004",
#                 "end": "2004",
#                 "ended": true
#             },
#             "name": "Mint-Aid",
#             "score": "19",
#             "sort-name": "Mint-Aid",
#             "type": "Group"
#         },
#         {
#             "id": "7fe6ce13-78e4-4dc0-9820-aa2f4acd844a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Punk Aid",
#             "score": "19",
#             "sort-name": "Punk Aid"
#         }
#     ],
#     "count": 419,
#     "created": "2016-08-23T13:46:09.669Z",
#     "offset": 0
# }

# %%
fak = 0
for i in range(len(firstaidkit["artists"])):
    if firstaidkit["artists"][i]["name"] == "First Aid Kit":
        print firstaidkit["artists"][i]
        fak = fak + 1
print
print str(fak) + " First Aid Kits"
# Out:
# {u'name': u'First Aid Kit', u'area': {u'sort-name': u'Sweden', u'id': u'23d10872-f5ae-3f0c-bf55-332788a16ecb', u'name': u'Sweden'}, u'country': u'SE', u'disambiguation': u'Swedish folk band', u'tags': [{u'count': 0, u'name': u'remember'}], u'life-span': {u'ended': None, u'begin': u'2007'}, u'sort-name': u'First Aid Kit', u'score': u'100', u'begin-area': {u'sort-name': u'Stockholm', u'id': u'1127ddc2-eab3-4662-8718-6adbdeea3b10', u'name': u'Stockholm'}, u'type': u'Group', u'id': u'373faa02-74d7-4b1d-9b47-7574ad510f8d'}
# {u'name': u'First Aid Kit', u'area': {u'sort-name': u'Spain', u'id': u'471c46a7-afc5-31c4-923c-d0444f5053a4', u'name': u'Spain'}, u'country': u'ES', u'disambiguation': u'Spanish indie electronic band', u'life-span': {u'ended': None, u'begin': u'2004'}, u'sort-name': u'First Aid Kit', u'score': u'100', u'begin-area': {u'sort-name': u'Barcelona', u'id': u'12c3b82e-fcab-4219-9bd5-792089d8280e', u'name': u'Barcelona'}, u'type': u'Group', u'id': u'e4466078-fb0f-4899-98a2-7c7dfeb14714'}
#
# 2 First Aid Kits

# %% [markdown]
# #### Quiz:
#
# Begin_area name for Queen?

# %%
queen = query_by_name(ARTIST_URL, query_type["simple"], "Queen")
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3AQueen&fmt=json

# %%
pretty_print(queen, indent=4)
# Out:
# {
#     "artists": [
#         {
#             "aliases": [
#                 {
#                     "begin-date": "2011",
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen + Adam Lambert",
#                     "primary": null,
#                     "sort-name": "Queen + Adam Lambert",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "disambiguation": "UK rock group",
#             "id": "0383dadf-2a4e-4d10-a46a-e9e041da8eb3",
#             "life-span": {
#                 "begin": "1970-06-27",
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen",
#             "tags": [
#                 {
#                     "count": 3,
#                     "name": "hard rock"
#                 },
#                 {
#                     "count": -2,
#                     "name": "80s"
#                 },
#                 {
#                     "count": -2,
#                     "name": "70s"
#                 },
#                 {
#                     "count": 3,
#                     "name": "british"
#                 },
#                 {
#                     "count": 0,
#                     "name": "english"
#                 },
#                 {
#                     "count": 0,
#                     "name": "uk"
#                 },
#                 {
#                     "count": 0,
#                     "name": "britannique"
#                 },
#                 {
#                     "count": -1,
#                     "name": "classic pop and rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "queen"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united kingdom"
#                 },
#                 {
#                     "count": 0,
#                     "name": "kind of magic"
#                 },
#                 {
#                     "count": -1,
#                     "name": "platinum"
#                 },
#                 {
#                     "count": 8,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "langham 1 studio bbc"
#                 },
#                 {
#                     "count": 0,
#                     "name": "band"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "glam rock"
#                 },
#                 {
#                     "count": 2,
#                     "name": "art rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "disco"
#                 },
#                 {
#                     "count": -2,
#                     "name": "90s"
#                 },
#                 {
#                     "count": 0,
#                     "name": "70's"
#                 },
#                 {
#                     "count": 0,
#                     "name": "80's"
#                 },
#                 {
#                     "count": -1,
#                     "name": "90's"
#                 },
#                 {
#                     "count": -1,
#                     "name": "pop-rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "pop/rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "queen family"
#                 },
#                 {
#                     "count": 0,
#                     "name": "progressive rock"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen",
#                     "primary": null,
#                     "sort-name": "Queen",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "2db42837-c832-3c27-b4a3-08198f75693c",
#                 "name": "Japan",
#                 "sort-name": "Japan"
#             },
#             "country": "JP",
#             "disambiguation": "character, voiced by \u677f\u91ce\u53cb\u7f8e / Itano Tomomi",
#             "gender": "female",
#             "id": "420ca290-76c5-41af-999e-564d7c71f1a7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "related-akb48"
#                 },
#                 {
#                     "count": 1,
#                     "name": "kamen rider w"
#                 }
#             ],
#             "type": "Character"
#         },
#         {
#             "disambiguation": "US rapper",
#             "id": "5eecaf18-02ec-47af-a4f2-7831db373419",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "b50415aa-637c-4631-b074-7debcdb36da9",
#             "life-span": {
#                 "begin": "1929-01-15",
#                 "ended": null
#             },
#             "name": "Queen Ida",
#             "score": "62",
#             "sort-name": "Queen Ida",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "id": "c7d8e75d-ce47-473e-a434-e46b316e4e2f",
#             "life-span": {
#                 "begin": "1992",
#                 "end": "1995",
#                 "ended": true
#             },
#             "name": "Bandit Queen",
#             "score": "62",
#             "sort-name": "Bandit Queen",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Dana Owens",
#                     "primary": null,
#                     "sort-name": "Dana Owens",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen Latifa",
#                     "primary": null,
#                     "sort-name": "Queen Latifa",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "5a2f83bb-e033-4d4b-9fea-9ca6f27cf751",
#                 "name": "Colts Neck Township",
#                 "sort-name": "Colts Neck Township"
#             },
#             "begin-area": {
#                 "id": "85c7cd5f-6fe2-4195-a44d-69fa390bd6ec",
#                 "name": "Newark",
#                 "sort-name": "Newark"
#             },
#             "gender": "female",
#             "id": "7a305f29-539a-456e-93b7-61b0e2ba3ef2",
#             "life-span": {
#                 "begin": "1970-03-18",
#                 "ended": null
#             },
#             "name": "Queen Latifah",
#             "score": "62",
#             "sort-name": "Queen Latifah",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "hip hop"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Acic Queen",
#                     "primary": null,
#                     "sort-name": "Acic Queen",
#                     "type": null
#                 }
#             ],
#             "id": "8a03436b-2120-4d04-9f3b-9e18753ba8b7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Acid Queen",
#             "score": "62",
#             "sort-name": "Acid Queen",
#             "type": "Group"
#         },
#         {
#             "gender": "female",
#             "id": "c6303af1-d66e-4e8a-930e-fe1d6ea5b781",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Majeeda",
#             "score": "62",
#             "sort-name": "Queen Majeeda",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "disambiguation": "German duo Ina M\u00fcller & Edda Schnittgard",
#             "id": "fd31549e-6a5f-4ff8-94fa-5a68638952fc",
#             "life-span": {
#                 "begin": "1994",
#                 "end": "2005",
#                 "ended": true
#             },
#             "name": "Queen Bee",
#             "score": "62",
#             "sort-name": "Queen Bee",
#             "type": "Group"
#         },
#         {
#             "id": "f45984aa-f1ca-41d8-898a-af07340ae244",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Pearly Queen",
#             "score": "62",
#             "sort-name": "Pearly Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "funk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "rhythm and blues"
#                 },
#                 {
#                     "count": 1,
#                     "name": "latin"
#                 },
#                 {
#                     "count": 1,
#                     "name": "latin funk"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "id": "8d25fda6-e74e-45ac-9695-7e3e6a7d0fac",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "B.B. Queen",
#             "score": "62",
#             "sort-name": "B.B. Queen"
#         },
#         {
#             "area": {
#                 "id": "08310658-51eb-3801-80de-5a0739207115",
#                 "name": "France",
#                 "sort-name": "France"
#             },
#             "country": "FR",
#             "id": "ea57c459-a6dd-40ea-b489-03b7a912be13",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Sister Queen",
#             "score": "62",
#             "sort-name": "Sister Queen",
#             "type": "Group"
#         },
#         {
#             "id": "b9de990e-2ece-42dd-827c-30c4ca4a99a4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen V",
#             "score": "62",
#             "sort-name": "Queen V"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen Elisabeth",
#                     "primary": null,
#                     "sort-name": "Queen Elisabeth",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "disambiguation": "British band with Julian Cope",
#             "id": "1e067199-f4cd-477b-9a87-7170e7ed4cf7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Elizabeth",
#             "score": "62",
#             "sort-name": "Queen Elizabeth",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "gender": "female",
#             "id": "9a86679d-7661-4633-b1b0-76a69922458c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Monica Queen",
#             "score": "62",
#             "sort-name": "Queen, Monica",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "country"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "08310658-51eb-3801-80de-5a0739207115",
#                 "name": "France",
#                 "sort-name": "France"
#             },
#             "country": "FR",
#             "id": "ee2d368e-3580-46d3-9de7-84110254b6c0",
#             "life-span": {
#                 "begin": "1977",
#                 "ended": null
#             },
#             "name": "Queen Samantha",
#             "score": "62",
#             "sort-name": "Queen Samantha",
#             "type": "Group"
#         },
#         {
#             "id": "eceb4f3d-95d9-4566-9fe2-a307fbcc3a4b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Black Queen",
#             "score": "62",
#             "sort-name": "Black Queen"
#         },
#         {
#             "area": {
#                 "id": "3906cf32-00a7-32df-93cc-4710c5f5a542",
#                 "name": "Puerto Rico",
#                 "sort-name": "Puerto Rico"
#             },
#             "country": "PR",
#             "gender": "female",
#             "id": "ff06ecc0-72a5-4a81-a253-d840d9aefb32",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Ivy Queen",
#             "score": "62",
#             "sort-name": "Ivy Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "reggaet\u00f3n"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "a71b0d32-7752-49e9-8594-2247ad6ac12c",
#                 "name": "Brooklyn",
#                 "sort-name": "Brooklyn"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "e6476e4f-ad4c-4e29-bd20-0cd622ffe441",
#             "life-span": {
#                 "begin": "1973",
#                 "ended": null
#             },
#             "name": "Queen Pen",
#             "score": "62",
#             "sort-name": "Pen, Queen",
#             "type": "Person"
#         },
#         {
#             "id": "fbd2bc49-d2dd-410d-a870-950e56f02d5b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Filter Queen",
#             "score": "62",
#             "sort-name": "Filter Queen"
#         },
#         {
#             "id": "26069161-b64d-4021-9c7e-7686dae8ffb4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Pork Queen",
#             "score": "62",
#             "sort-name": "Pork Queen"
#         },
#         {
#             "id": "8eb2fc14-e41d-4c02-b3f2-4a4fa3d88664",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Witch Queen",
#             "score": "62",
#             "sort-name": "Witch Queen"
#         },
#         {
#             "id": "8636f35d-0e6c-447e-a77f-718a85124b80",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Stampede Queen",
#             "score": "62",
#             "sort-name": "Stampede Queen",
#             "type": "Group"
#         },
#         {
#             "id": "b46cb0af-039b-4966-9c3e-43a29823778e",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Jenny Queen",
#             "score": "62",
#             "sort-name": "Queen, Jenny",
#             "type": "Person"
#         },
#         {
#             "id": "e74250aa-8f69-426c-9a10-944e53ac5dba",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Mecca",
#             "score": "62",
#             "sort-name": "Queen Mecca"
#         }
#     ],
#     "count": 250,
#     "created": "2016-08-23T13:46:09.669Z",
#     "offset": 0
# }

# %%
for each in range(len(queen["artists"])):
    if queen["artists"][each]["name"] == "Queen":
        print queen["artists"]
# Out:
# [{u'name': u'Queen', u'area': {u'sort-name': u'United Kingdom', u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed', u'name': u'United Kingdom'}, u'country': u'GB', u'disambiguation': u'UK rock group', u'tags': [{u'count': 3, u'name': u'hard rock'}, {u'count': -2, u'name': u'80s'}, {u'count': -2, u'name': u'70s'}, {u'count': 3, u'name': u'british'}, {u'count': 0, u'name': u'english'}, {u'count': 0, u'name': u'uk'}, {u'count': 0, u'name': u'britannique'}, {u'count': -1, u'name': u'classic pop and rock'}, {u'count': -1, u'name': u'queen'}, {u'count': 0, u'name': u'united kingdom'}, {u'count': 0, u'name': u'kind of magic'}, {u'count': -1, u'name': u'platinum'}, {u'count': 8, u'name': u'rock'}, {u'count': 0, u'name': u'langham 1 studio bbc'}, {u'count': 0, u'name': u'band'}, {u'count': 1, u'name': u'pop rock'}, {u'count': 1, u'name': u'glam rock'}, {u'count': 2, u'name': u'art rock'}, {u'count': 0, u'name': u'disco'}, {u'count': -2, u'name': u'90s'}, {u'count': 0, u'name': u"70's"}, {u'count': 0, u'name': u"80's"}, {u'count': -1, u'name': u"90's"}, {u'count': -1, u'name': u'pop-rock'}, {u'count': -1, u'name': u'pop/rock'}, {u'count': -1, u'name': u'queen family'}, {u'count': 0, u'name': u'progressive rock'}], u'life-span': {u'ended': None, u'begin': u'1970-06-27'}, u'sort-name': u'Queen', u'score': u'100', u'begin-area': {u'sort-name': u'London', u'id': u'f03d09b3-39dc-4083-afd6-159e3f0d462f', u'name': u'London'}, u'type': u'Group', u'id': u'0383dadf-2a4e-4d10-a46a-e9e041da8eb3', u'aliases': [{u'name': u'Queen + Adam Lambert', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen + Adam Lambert', u'type': None, u'begin-date': u'2011'}]}, {u'name': u'Queen', u'area': {u'sort-name': u'Japan', u'id': u'2db42837-c832-3c27-b4a3-08198f75693c', u'name': u'Japan'}, u'gender': u'female', u'disambiguation': u'character, voiced by \u677f\u91ce\u53cb\u7f8e / Itano Tomomi', u'tags': [{u'count': 1, u'name': u'related-akb48'}, {u'count': 1, u'name': u'kamen rider w'}], u'life-span': {u'ended': None}, u'sort-name': u'Queen', u'score': u'100', u'country': u'JP', u'type': u'Character', u'id': u'420ca290-76c5-41af-999e-564d7c71f1a7', u'aliases': [{u'name': u'Queen', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen', u'type': None, u'begin-date': None}]}, {u'name': u'Queen', u'disambiguation': u'US rapper', u'life-span': {u'ended': None}, u'sort-name': u'Queen', u'score': u'100', u'id': u'5eecaf18-02ec-47af-a4f2-7831db373419'}, {u'name': u'Queen Ida', u'area': {u'sort-name': u'United States', u'id': u'489ce91b-6658-3307-9877-795b68554c98', u'name': u'United States'}, u'gender': u'female', u'life-span': {u'ended': None, u'begin': u'1929-01-15'}, u'sort-name': u'Queen Ida', u'score': u'62', u'country': u'US', u'type': u'Person', u'id': u'b50415aa-637c-4631-b074-7debcdb36da9'}, {u'name': u'Bandit Queen', u'area': {u'sort-name': u'United Kingdom', u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed', u'name': u'United Kingdom'}, u'country': u'GB', u'life-span': {u'ended': True, u'begin': u'1992', u'end': u'1995'}, u'sort-name': u'Bandit Queen', u'score': u'62', u'type': u'Group', u'id': u'c7d8e75d-ce47-473e-a434-e46b316e4e2f'}, {u'name': u'Queen Latifah', u'area': {u'sort-name': u'Colts Neck Township', u'id': u'5a2f83bb-e033-4d4b-9fea-9ca6f27cf751', u'name': u'Colts Neck Township'}, u'gender': u'female', u'life-span': {u'ended': None, u'begin': u'1970-03-18'}, u'tags': [{u'count': 1, u'name': u'hip hop'}], u'sort-name': u'Queen Latifah', u'score': u'62', u'begin-area': {u'sort-name': u'Newark', u'id': u'85c7cd5f-6fe2-4195-a44d-69fa390bd6ec', u'name': u'Newark'}, u'type': u'Person', u'id': u'7a305f29-539a-456e-93b7-61b0e2ba3ef2', u'aliases': [{u'name': u'Dana Owens', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Dana Owens', u'type': None, u'begin-date': None}, {u'name': u'Queen Latifa', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen Latifa', u'type': None, u'begin- ...
# [{u'name': u'Queen', u'area': {u'sort-name': u'United Kingdom', u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed', u'name': u'United Kingdom'}, u'country': u'GB', u'disambiguation': u'UK rock group', u'tags': [{u'count': 3, u'name': u'hard rock'}, {u'count': -2, u'name': u'80s'}, {u'count': -2, u'name': u'70s'}, {u'count': 3, u'name': u'british'}, {u'count': 0, u'name': u'english'}, {u'count': 0, u'name': u'uk'}, {u'count': 0, u'name': u'britannique'}, {u'count': -1, u'name': u'classic pop and rock'}, {u'count': -1, u'name': u'queen'}, {u'count': 0, u'name': u'united kingdom'}, {u'count': 0, u'name': u'kind of magic'}, {u'count': -1, u'name': u'platinum'}, {u'count': 8, u'name': u'rock'}, {u'count': 0, u'name': u'langham 1 studio bbc'}, {u'count': 0, u'name': u'band'}, {u'count': 1, u'name': u'pop rock'}, {u'count': 1, u'name': u'glam rock'}, {u'count': 2, u'name': u'art rock'}, {u'count': 0, u'name': u'disco'}, {u'count': -2, u'name': u'90s'}, {u'count': 0, u'name': u"70's"}, {u'count': 0, u'name': u"80's"}, {u'count': -1, u'name': u"90's"}, {u'count': -1, u'name': u'pop-rock'}, {u'count': -1, u'name': u'pop/rock'}, {u'count': -1, u'name': u'queen family'}, {u'count': 0, u'name': u'progressive rock'}], u'life-span': {u'ended': None, u'begin': u'1970-06-27'}, u'sort-name': u'Queen', u'score': u'100', u'begin-area': {u'sort-name': u'London', u'id': u'f03d09b3-39dc-4083-afd6-159e3f0d462f', u'name': u'London'}, u'type': u'Group', u'id': u'0383dadf-2a4e-4d10-a46a-e9e041da8eb3', u'aliases': [{u'name': u'Queen + Adam Lambert', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen + Adam Lambert', u'type': None, u'begin-date': u'2011'}]}, {u'name': u'Queen', u'area': {u'sort-name': u'Japan', u'id': u'2db42837-c832-3c27-b4a3-08198f75693c', u'name': u'Japan'}, u'gender': u'female', u'disambiguation': u'character, voiced by \u677f\u91ce\u53cb\u7f8e / Itano Tomomi', u'tags': [{u'count': 1, u'name': u'related-akb48'}, {u'count': 1, u'name': u'kamen rider w'}], u'life-span': {u'ended': None}, u'sort-name': u'Queen', u'score': u'100', u'country': u'JP', u'type': u'Character', u'id': u'420ca290-76c5-41af-999e-564d7c71f1a7', u'aliases': [{u'name': u'Queen', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen', u'type': None, u'begin-date': None}]}, {u'name': u'Queen', u'disambiguation': u'US rapper', u'life-span': {u'ended': None}, u'sort-name': u'Queen', u'score': u'100', u'id': u'5eecaf18-02ec-47af-a4f2-7831db373419'}, {u'name': u'Queen Ida', u'area': {u'sort-name': u'United States', u'id': u'489ce91b-6658-3307-9877-795b68554c98', u'name': u'United States'}, u'gender': u'female', u'life-span': {u'ended': None, u'begin': u'1929-01-15'}, u'sort-name': u'Queen Ida', u'score': u'62', u'country': u'US', u'type': u'Person', u'id': u'b50415aa-637c-4631-b074-7debcdb36da9'}, {u'name': u'Bandit Queen', u'area': {u'sort-name': u'United Kingdom', u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed', u'name': u'United Kingdom'}, u'country': u'GB', u'life-span': {u'ended': True, u'begin': u'1992', u'end': u'1995'}, u'sort-name': u'Bandit Queen', u'score': u'62', u'type': u'Group', u'id': u'c7d8e75d-ce47-473e-a434-e46b316e4e2f'}, {u'name': u'Queen Latifah', u'area': {u'sort-name': u'Colts Neck Township', u'id': u'5a2f83bb-e033-4d4b-9fea-9ca6f27cf751', u'name': u'Colts Neck Township'}, u'gender': u'female', u'life-span': {u'ended': None, u'begin': u'1970-03-18'}, u'tags': [{u'count': 1, u'name': u'hip hop'}], u'sort-name': u'Queen Latifah', u'score': u'62', u'begin-area': {u'sort-name': u'Newark', u'id': u'85c7cd5f-6fe2-4195-a44d-69fa390bd6ec', u'name': u'Newark'}, u'type': u'Person', u'id': u'7a305f29-539a-456e-93b7-61b0e2ba3ef2', u'aliases': [{u'name': u'Dana Owens', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Dana Owens', u'type': None, u'begin-date': None}, {u'name': u'Queen Latifa', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen Latifa', u'type': None, u'begin- ...
# [{u'name': u'Queen', u'area': {u'sort-name': u'United Kingdom', u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed', u'name': u'United Kingdom'}, u'country': u'GB', u'disambiguation': u'UK rock group', u'tags': [{u'count': 3, u'name': u'hard rock'}, {u'count': -2, u'name': u'80s'}, {u'count': -2, u'name': u'70s'}, {u'count': 3, u'name': u'british'}, {u'count': 0, u'name': u'english'}, {u'count': 0, u'name': u'uk'}, {u'count': 0, u'name': u'britannique'}, {u'count': -1, u'name': u'classic pop and rock'}, {u'count': -1, u'name': u'queen'}, {u'count': 0, u'name': u'united kingdom'}, {u'count': 0, u'name': u'kind of magic'}, {u'count': -1, u'name': u'platinum'}, {u'count': 8, u'name': u'rock'}, {u'count': 0, u'name': u'langham 1 studio bbc'}, {u'count': 0, u'name': u'band'}, {u'count': 1, u'name': u'pop rock'}, {u'count': 1, u'name': u'glam rock'}, {u'count': 2, u'name': u'art rock'}, {u'count': 0, u'name': u'disco'}, {u'count': -2, u'name': u'90s'}, {u'count': 0, u'name': u"70's"}, {u'count': 0, u'name': u"80's"}, {u'count': -1, u'name': u"90's"}, {u'count': -1, u'name': u'pop-rock'}, {u'count': -1, u'name': u'pop/rock'}, {u'count': -1, u'name': u'queen family'}, {u'count': 0, u'name': u'progressive rock'}], u'life-span': {u'ended': None, u'begin': u'1970-06-27'}, u'sort-name': u'Queen', u'score': u'100', u'begin-area': {u'sort-name': u'London', u'id': u'f03d09b3-39dc-4083-afd6-159e3f0d462f', u'name': u'London'}, u'type': u'Group', u'id': u'0383dadf-2a4e-4d10-a46a-e9e041da8eb3', u'aliases': [{u'name': u'Queen + Adam Lambert', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen + Adam Lambert', u'type': None, u'begin-date': u'2011'}]}, {u'name': u'Queen', u'area': {u'sort-name': u'Japan', u'id': u'2db42837-c832-3c27-b4a3-08198f75693c', u'name': u'Japan'}, u'gender': u'female', u'disambiguation': u'character, voiced by \u677f\u91ce\u53cb\u7f8e / Itano Tomomi', u'tags': [{u'count': 1, u'name': u'related-akb48'}, {u'count': 1, u'name': u'kamen rider w'}], u'life-span': {u'ended': None}, u'sort-name': u'Queen', u'score': u'100', u'country': u'JP', u'type': u'Character', u'id': u'420ca290-76c5-41af-999e-564d7c71f1a7', u'aliases': [{u'name': u'Queen', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen', u'type': None, u'begin-date': None}]}, {u'name': u'Queen', u'disambiguation': u'US rapper', u'life-span': {u'ended': None}, u'sort-name': u'Queen', u'score': u'100', u'id': u'5eecaf18-02ec-47af-a4f2-7831db373419'}, {u'name': u'Queen Ida', u'area': {u'sort-name': u'United States', u'id': u'489ce91b-6658-3307-9877-795b68554c98', u'name': u'United States'}, u'gender': u'female', u'life-span': {u'ended': None, u'begin': u'1929-01-15'}, u'sort-name': u'Queen Ida', u'score': u'62', u'country': u'US', u'type': u'Person', u'id': u'b50415aa-637c-4631-b074-7debcdb36da9'}, {u'name': u'Bandit Queen', u'area': {u'sort-name': u'United Kingdom', u'id': u'8a754a16-0027-3a29-b6d7-2b40ea0481ed', u'name': u'United Kingdom'}, u'country': u'GB', u'life-span': {u'ended': True, u'begin': u'1992', u'end': u'1995'}, u'sort-name': u'Bandit Queen', u'score': u'62', u'type': u'Group', u'id': u'c7d8e75d-ce47-473e-a434-e46b316e4e2f'}, {u'name': u'Queen Latifah', u'area': {u'sort-name': u'Colts Neck Township', u'id': u'5a2f83bb-e033-4d4b-9fea-9ca6f27cf751', u'name': u'Colts Neck Township'}, u'gender': u'female', u'life-span': {u'ended': None, u'begin': u'1970-03-18'}, u'tags': [{u'count': 1, u'name': u'hip hop'}], u'sort-name': u'Queen Latifah', u'score': u'62', u'begin-area': {u'sort-name': u'Newark', u'id': u'85c7cd5f-6fe2-4195-a44d-69fa390bd6ec', u'name': u'Newark'}, u'type': u'Person', u'id': u'7a305f29-539a-456e-93b7-61b0e2ba3ef2', u'aliases': [{u'name': u'Dana Owens', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Dana Owens', u'type': None, u'begin-date': None}, {u'name': u'Queen Latifa', u'locale': None, u'end-date': None, u'primary': None, u'sort-name': u'Queen Latifa', u'type': None, u'begin- ...

# %%
queen["artists"][0]["begin-area"]["name"]
# Out:
# u'London'

# %% [markdown]
# #### Quiz:
#
# Spanish Alias for the Beatles?

# %%
beatles = query_by_name(ARTIST_URL, query_type["aliases"], "beatles")
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3Abeatles&fmt=json&inc=aliases

# %%
pretty_print(beatles, indent=4)
# Out:
# {
#     "artists": [
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "ko",
#                     "name": "\ub354 \ube44\ud2c0\uc988",
#                     "primary": true,
#                     "sort-name": "\ub354 \ube44\ud2c0\uc988",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "ja",
#                     "name": "\u30b6\u30fb\u30d3\u30fc\u30c8\u30eb\u30ba",
#                     "primary": true,
#                     "sort-name": "\u30d3\u30fc\u30c8\u30eb\u30ba (\u30b6)",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "B",
#                     "primary": null,
#                     "sort-name": "B",
#                     "type": "Search hint"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Be",
#                     "primary": null,
#                     "sort-name": "Be",
#                     "type": "Search hint"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Beat",
#                     "primary": null,
#                     "sort-name": "Beat",
#                     "type": "Search hint"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "en",
#                     "name": "Beatles",
#                     "primary": null,
#                     "sort-name": "Beatles",
#                     "type": "Artist name"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Beetles",
#                     "primary": null,
#                     "sort-name": "Beetles",
#                     "type": "Search hint"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "fab four",
#                     "primary": null,
#                     "sort-name": "fab four",
#                     "type": "Search hint"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "es",
#                     "name": "Los Beatles",
#                     "primary": true,
#                     "sort-name": "Los Beatles",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "en",
#                     "name": "The Beatles",
#                     "primary": true,
#                     "sort-name": "Beatles, The",
#                     "type": "Artist name"
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "ru",
#                     "name": "\u0411\u0438\u0442\u043b\u0437",
#                     "primary": true,
#                     "sort-name": "\u0411\u0438\u0442\u043b\u0437",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "zh_Hans",
#                     "name": "\u62ab\u5934\u58eb",
#                     "primary": true,
#                     "sort-name": "\u62ab\u5934\u58eb",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": "zh_Hant",
#                     "name": "\u62ab\u982d\u56db",
#                     "primary": true,
#                     "sort-name": "\u62ab\u982d\u56db",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "c249c30e-88ab-4b2f-a745-96a25bd7afee",
#                 "name": "Liverpool",
#                 "sort-name": "Liverpool"
#             },
#             "country": "GB",
#             "id": "b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d",
#             "life-span": {
#                 "begin": "1957-03",
#                 "end": "1970-04-10",
#                 "ended": true
#             },
#             "name": "The Beatles",
#             "score": "100",
#             "sort-name": "Beatles, The",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "uk"
#                 },
#                 {
#                     "count": 11,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "english"
#                 },
#                 {
#                     "count": 0,
#                     "name": "overrated"
#                 },
#                 {
#                     "count": 0,
#                     "name": "parlophone"
#                 },
#                 {
#                     "count": 0,
#                     "name": "60s"
#                 },
#                 {
#                     "count": 0,
#                     "name": "pop-rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "pop/rock"
#                 },
#                 {
#                     "count": 2,
#                     "name": "psychedelic pop"
#                 },
#                 {
#                     "count": 2,
#                     "name": "rock & roll"
#                 },
#                 {
#                     "count": 1,
#                     "name": "british invasion"
#                 },
#                 {
#                     "count": 0,
#                     "name": "folk-rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "rock roll"
#                 },
#                 {
#                     "count": 0,
#                     "name": "tribute albums"
#                 },
#                 {
#                     "count": 0,
#                     "name": "pop-metal"
#                 },
#                 {
#                     "count": 0,
#                     "name": "indie rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "heavy metal"
#                 },
#                 {
#                     "count": 0,
#                     "name": "adult alternative pop rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "british psychedelia"
#                 },
#                 {
#                     "count": 0,
#                     "name": "orchestral"
#                 },
#                 {
#                     "count": 0,
#                     "name": "orchestral pop"
#                 },
#                 {
#                     "count": 0,
#                     "name": "instrumental pop"
#                 },
#                 {
#                     "count": 0,
#                     "name": "psychedelic"
#                 },
#                 {
#                     "count": 0,
#                     "name": "singer songwriter"
#                 },
#                 {
#                     "count": 1,
#                     "name": "classical pop"
#                 },
#                 {
#                     "count": 0,
#                     "name": "classic pop and rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "britpop"
#                 },
#                 {
#                     "count": 0,
#                     "name": "progressive rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "1"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united kingdom"
#                 },
#                 {
#                     "count": 0,
#                     "name": "rock and roll"
#                 },
#                 {
#                     "count": 2,
#                     "name": "experimental"
#                 },
#                 {
#                     "count": 0,
#                     "name": "male vocalists"
#                 },
#                 {
#                     "count": 1,
#                     "name": "liverpool"
#                 },
#                 {
#                     "count": 10,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 0,
#                     "name": "one beatles"
#                 },
#                 {
#                     "count": 5,
#                     "name": "british"
#                 },
#                 {
#                     "count": 3,
#                     "name": "pop rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "a filk artist"
#                 },
#                 {
#                     "count": 0,
#                     "name": "hair metal"
#                 },
#                 {
#                     "count": 2,
#                     "name": "psychedelic rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "80s"
#                 },
#                 {
#                     "count": 0,
#                     "name": "the-beatles"
#                 },
#                 {
#                     "count": 0,
#                     "name": "bbc"
#                 },
#                 {
#                     "count": 1,
#                     "name": "british rhythm & blues"
#                 },
#                 {
#                     "count": 1,
#                     "name": "rhythm & blues"
#                 },
#                 {
#                     "count": 3,
#                     "name": "merseybeat"
#                 },
#                 {
#                     "count": 1,
#                     "name": "folk pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "folk rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "sunshine pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "art pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "art rock"
#                 },
#                 {
#                     "count": 2,
#                     "name": "hard rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "blues rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "beat music"
#                 },
#                 {
#                     "count": 1,
#                     "name": "boys band"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "2db42837-c832-3c27-b4a3-08198f75693c",
#                 "name": "Japan",
#                 "sort-name": "Japan"
#             },
#             "begin-area": {
#                 "id": "8dc97297-ac95-4d33-82bc-e07fab26fb5f",
#                 "name": "Tokyo",
#                 "sort-name": "Tokyo"
#             },
#             "country": "JP",
#             "disambiguation": "Japanese",
#             "id": "bc569a61-dd62-4758-86c6-e99dcb1fdda6",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Tokyo Beatles",
#             "score": "100",
#             "sort-name": "Tokyo Beatles"
#         },
#         {
#             "id": "3133aeb8-9982-4e11-a8ff-5477996a80bf",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Beatles Chillout",
#             "score": "100",
#             "sort-name": "Beatles Chillout"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "id": "dc146c82-7709-41ee-8322-0d4c9fea0378",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Fab Beatles",
#             "score": "100",
#             "sort-name": "Fab Beatles",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "106e0bec-b638-3b37-b731-f53d507dc00e",
#                 "name": "Australia",
#                 "sort-name": "Australia"
#             },
#             "country": "AU",
#             "disambiguation": "The Beatles tribute band",
#             "id": "7cac6d47-ef4e-4347-8835-63ed3f2e74a7",
#             "life-span": {
#                 "begin": "2011",
#                 "ended": null
#             },
#             "name": "Beatles Back2Back",
#             "score": "100",
#             "sort-name": "Beatles Back2Back",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "disambiguation": "The Beatles tribute band",
#             "id": "ad60d963-44f1-4b41-b785-8284edcaaffe",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Counterfeit Beatles",
#             "score": "100",
#             "sort-name": "Counterfeit Beatles",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "dbe53871-db21-47ea-a0c3-3ab58317a3ab",
#                 "name": "Gainesville",
#                 "sort-name": "Gainesville"
#             },
#             "begin-area": {
#                 "id": "dbe53871-db21-47ea-a0c3-3ab58317a3ab",
#                 "name": "Gainesville",
#                 "sort-name": "Gainesville"
#             },
#             "disambiguation": "Beatles Cover Band",
#             "end-area": {
#                 "id": "dbe53871-db21-47ea-a0c3-3ab58317a3ab",
#                 "name": "Gainesville",
#                 "sort-name": "Gainesville"
#             },
#             "id": "de0769fa-7c32-4706-9c8c-03631c90f208",
#             "life-span": {
#                 "begin": "2005",
#                 "end": "2015-04-19",
#                 "ended": true
#             },
#             "name": "Shitty Beatles",
#             "score": "100",
#             "sort-name": "Shitty Beatles",
#             "type": "Group"
#         },
#         {
#             "id": "35574687-3a4d-4b30-a01a-43fea73b3430",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Them Beatles",
#             "score": "100",
#             "sort-name": "Them Beatles",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Tape-Beatles",
#                     "primary": null,
#                     "sort-name": "Tape-Beatles",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "3fc3b364-665e-4875-a9ff-3699cd716152",
#                 "name": "Iowa City",
#                 "sort-name": "Iowa City"
#             },
#             "country": "US",
#             "id": "5e685f9e-83bb-423c-acfa-487e34f15ffd",
#             "life-span": {
#                 "begin": "1986-12",
#                 "ended": null
#             },
#             "name": "The Tape-beatles",
#             "score": "80",
#             "sort-name": "Tape-beatles, The",
#             "type": "Group"
#         },
#         {
#             "id": "333b16c0-c1fc-4fa0-ab58-367adf2c8e2e",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Savage Young Beatles",
#             "score": "80",
#             "sort-name": "Savage Young Beatles, The",
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Beatles Revival Band",
#                     "primary": null,
#                     "sort-name": "Beatles Revival Band",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "disambiguation": "german cover band",
#             "id": "0f697bc6-6df7-41c9-b550-39981e520d70",
#             "life-span": {
#                 "begin": "1976",
#                 "ended": null
#             },
#             "name": "The Beatles Revival Band",
#             "score": "80",
#             "sort-name": "Beatles Revival Band, The",
#             "type": "Group"
#         },
#         {
#             "id": "e67ffb2a-0d5e-472d-9f3b-02d2ed7adc9a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Moog Beatles",
#             "score": "80",
#             "sort-name": "Moog Beatles, The",
#             "type": "Group"
#         },
#         {
#             "id": "4c3d0136-9235-4c50-b136-be49d17163df",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Black Beatles",
#             "score": "80",
#             "sort-name": "Black Beatles, The"
#         },
#         {
#             "id": "7383113a-2b44-4fd1-a2b1-277ca68803b7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Better Beatles",
#             "score": "80",
#             "sort-name": "Better Beatles, The",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "51d34c28-61bf-3d21-849f-7492672a9d44",
#                 "name": "Czech Republic",
#                 "sort-name": "Czech Republic"
#             },
#             "country": "CZ",
#             "disambiguation": "Czech 'The Beatles' tribute band",
#             "id": "5153cd90-37c6-4fa0-8da6-dbf5513b4a44",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Beatles Revival",
#             "score": "80",
#             "sort-name": "Beatles Revival, The",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "c249c30e-88ab-4b2f-a745-96a25bd7afee",
#                 "name": "Liverpool",
#                 "sort-name": "Liverpool"
#             },
#             "id": "ec996b5f-89c8-4dd6-8063-1bd8df438a00",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Backbeat Beatles",
#             "score": "80",
#             "sort-name": "Backbeat Beatles, The",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "c249c30e-88ab-4b2f-a745-96a25bd7afee",
#                 "name": "Liverpool",
#                 "sort-name": "Liverpool"
#             },
#             "begin-area": {
#                 "id": "c249c30e-88ab-4b2f-a745-96a25bd7afee",
#                 "name": "Liverpool",
#                 "sort-name": "Liverpool"
#             },
#             "disambiguation": "Beatles Cover Band",
#             "id": "31f6812d-12ab-406f-a13d-ad54976e49c6",
#             "life-span": {
#                 "begin": "1989",
#                 "ended": null
#             },
#             "name": "The Cavern Beatles",
#             "score": "80",
#             "sort-name": "Beatles Cover Band",
#             "type": "Group"
#         },
#         {
#             "id": "75a2dff3-b370-4caa-9447-d9756d28243b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Suck My Beatles",
#             "score": "80",
#             "sort-name": "Suck My Beatles"
#         },
#         {
#             "id": "f540dcbe-4ae8-45c7-817b-372241202276",
#             "life-span": {
#                 "begin": "1998",
#                 "ended": null
#             },
#             "name": "Not The Beatles",
#             "score": "80",
#             "sort-name": "Not The Beatles",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "id": "78f48270-d409-4454-b020-f33325da8e5b",
#             "life-span": {
#                 "begin": "1980-03",
#                 "ended": null
#             },
#             "name": "The Bootleg Beatles",
#             "score": "80",
#             "sort-name": "Bootleg Beatles, The",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "rock"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "759f9567-9107-40ef-a825-e57824a62e70",
#                 "name": "St. Louis",
#                 "sort-name": "St. Louis"
#             },
#             "begin-area": {
#                 "id": "759f9567-9107-40ef-a825-e57824a62e70",
#                 "name": "St. Louis",
#                 "sort-name": "St. Louis"
#             },
#             "disambiguation": "Beatles tribute band from St. Louis",
#             "id": "ad188e81-565a-4ea3-96bc-9cab1feae91a",
#             "life-span": {
#                 "begin": "1988",
#                 "ended": null
#             },
#             "name": "Pepperland: The Beatles Revue",
#             "score": "80",
#             "sort-name": "Pepperland: The Beatles Revue",
#             "type": "Group"
#         },
#         {
#             "id": "a7f3892a-24e5-4807-9fd9-99e0195588e0",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Vienna Beatles",
#             "score": "80",
#             "sort-name": "The Vienna Beatles"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "begin-area": {
#                 "id": "5d668739-7f88-4062-9bc5-11a90e838310",
#                 "name": "Braunschweig",
#                 "sort-name": "Braunschweig"
#             },
#             "country": "DE",
#             "disambiguation": "Beatles Tribute Band",
#             "id": "898e211b-06ad-460b-85ee-cd6ac337ef79",
#             "life-span": {
#                 "begin": "2009",
#                 "ended": null
#             },
#             "name": "The Beatles Connection",
#             "score": "80",
#             "sort-name": "Beatles Connection, The",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "Beatles Tribute Band",
#             "id": "abdd68e9-cd78-453e-a0d6-315dc73cf0e4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Liverpool Lads a Beatles Tribute",
#             "score": "70",
#             "sort-name": "Liverpool Lads",
#             "type": "Group"
#         },
#         {
#             "id": "6527acb3-0451-4450-a7e8-b88f86473e4c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Ultimate Beatles Cover Band",
#             "score": "70",
#             "sort-name": "Ultimate Beatles Cover Band, The",
#             "type": "Group"
#         }
#     ],
#     "count": 28,
#     "created": "2016-08-23T13:46:09.669Z",
#     "offset": 0
# }

# %%
for i in range(len(beatles["artists"][0]["aliases"])):
    if beatles["artists"][0]["aliases"][i]["locale"] == "es":
        print beatles["artists"][0]["aliases"][i]["name"]
# Out:
# Los Beatles

# %% [markdown]
# #### Quiz:
#
# Nirvana Disambiguation?

# %%
nirvana = query_by_name(ARTIST_URL, query_type["simple"], "Nirvana")
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3ANirvana&fmt=json

# %%
pretty_print(nirvana, indent=4)
# Out:
# {
#     "artists": [
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Nirvana US",
#                     "primary": null,
#                     "sort-name": "Nirvana US",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "a640b45c-c173-49b1-8030-973603e895b5",
#                 "name": "Aberdeen",
#                 "sort-name": "Aberdeen"
#             },
#             "country": "US",
#             "disambiguation": "90s US grunge band",
#             "id": "5b11f4ce-a62d-471e-81fc-a69a8278c7da",
#             "life-span": {
#                 "begin": "1988-01",
#                 "end": "1994-04-05",
#                 "ended": true
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 0,
#                     "name": "legendary"
#                 },
#                 {
#                     "count": 0,
#                     "name": "90"
#                 },
#                 {
#                     "count": 1,
#                     "name": "seattle"
#                 },
#                 {
#                     "count": 0,
#                     "name": "northwest"
#                 },
#                 {
#                     "count": 0,
#                     "name": "alternative"
#                 },
#                 {
#                     "count": 0,
#                     "name": "rock and indie"
#                 },
#                 {
#                     "count": 1,
#                     "name": "usa"
#                 },
#                 {
#                     "count": 0,
#                     "name": "am\u00e9ricain"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united states"
#                 },
#                 {
#                     "count": 0,
#                     "name": "kurt cobain"
#                 },
#                 {
#                     "count": 1,
#                     "name": "90s"
#                 },
#                 {
#                     "count": 4,
#                     "name": "alternative rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "band"
#                 },
#                 {
#                     "count": 13,
#                     "name": "grunge"
#                 },
#                 {
#                     "count": 9,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "acoustic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "noise rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "nirvana"
#                 },
#                 {
#                     "count": 5,
#                     "name": "american"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "disambiguation": "60s band from the UK",
#             "id": "9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6",
#             "life-span": {
#                 "begin": "1967",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "progressive rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "orchestral"
#                 },
#                 {
#                     "count": 1,
#                     "name": "british"
#                 },
#                 {
#                     "count": 1,
#                     "name": "power pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "psychedelic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "soft rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "symphonic rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "english"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "6a264f94-6ff1-30b1-9a81-41f7bfabd616",
#                 "name": "Finland",
#                 "sort-name": "Finland"
#             },
#             "country": "FI",
#             "disambiguation": "Early 1980's Finnish punk band",
#             "id": "85af0709-95db-4fbc-801a-120e9f4766d0",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "finland"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "disambiguation": "founded in 1987 by a Michael Jackson double/imitator",
#             "id": "3aa878c0-224b-41e5-abd1-63be359d2bca",
#             "life-span": {
#                 "begin": "1987",
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana"
#         },
#         {
#             "disambiguation": "French band from Martigues, activ during the 70s.",
#             "id": "c49d69dc-e008-47cf-b5ff-160fafb1fe1f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana",
#             "score": "100",
#             "sort-name": "Nirvana"
#         },
#         {
#             "id": "b305320e-c158-43f4-b5be-4450e2f99a32",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "El Nirvana",
#             "score": "62",
#             "sort-name": "Nirvana, El"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Nirvana",
#                     "primary": null,
#                     "sort-name": "Nirvana",
#                     "type": null
#                 },
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Prophet 2002",
#                     "primary": null,
#                     "sort-name": "Prophet 2002",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "23d10872-f5ae-3f0c-bf55-332788a16ecb",
#                 "name": "Sweden",
#                 "sort-name": "Sweden"
#             },
#             "country": "SE",
#             "disambiguation": "Swedish death metal band",
#             "id": "f2dfdff9-3862-4be0-bf85-9c833fa3059e",
#             "life-span": {
#                 "begin": "1988",
#                 "ended": null
#             },
#             "name": "Nirvana 2002",
#             "score": "62",
#             "sort-name": "Nirvana 2002",
#             "type": "Group"
#         },
#         {
#             "id": "329c04ae-3b73-4ca3-996f-75608ab1befb",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Singh",
#             "score": "62",
#             "sort-name": "Singh, Nirvana",
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "id": "c3a64a25-251b-4d03-afba-1471440245b8",
#             "life-span": {
#                 "begin": "2009",
#                 "ended": null
#             },
#             "name": "Approaching Nirvana",
#             "score": "62",
#             "sort-name": "Approaching Nirvana",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "206419e0-3a7a-49ce-8437-4e757767d02b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Savoury",
#             "score": "62",
#             "sort-name": "Savoury, Nirvana",
#             "type": "Person"
#         },
#         {
#             "id": "86f9ae24-ba2a-4d55-9275-0b89b85f6e3a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Weed Nirvana",
#             "score": "62",
#             "sort-name": "Weed Nirvana"
#         },
#         {
#             "area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "name": "Graz",
#                 "sort-name": "Graz"
#             },
#             "begin-area": {
#                 "id": "e8ad73e9-9e7f-41c4-a395-6e29260ff1df",
#                 "name": "Graz",
#                 "sort-name": "Graz"
#             },
#             "disambiguation": "Nirvana-Coverband",
#             "id": "46d8dae4-abec-438b-9c62-a3dbb2aaa1b7",
#             "life-span": {
#                 "begin": "2000",
#                 "ended": null
#             },
#             "name": "Nirvana Teen Spirit",
#             "score": "50",
#             "sort-name": "Nirvana Teen Spirit",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau"
#             },
#             "begin-area": {
#                 "id": "c621114d-73cc-4832-8afe-f13dc261e5af",
#                 "name": "Gatineau",
#                 "sort-name": "Gatineau"
#             },
#             "id": "02c4e6bb-7b7a-4686-8c23-df01bfd42b0e",
#             "life-span": {
#                 "begin": "2012-04-05",
#                 "ended": null
#             },
#             "name": "Sappy Nirvana Tribute",
#             "score": "50",
#             "sort-name": "Sappy Nirvana Tribute",
#             "type": "Group"
#         },
#         {
#             "id": "e1388435-f80d-434a-9980-f1c9f5aa9b90",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Nirvana Sitar & String Group",
#             "score": "43",
#             "sort-name": "Nirvana Sitar & String Group"
#         }
#     ],
#     "count": 14,
#     "created": "2016-08-23T13:46:09.669Z",
#     "offset": 0
# }

# %%
nirvana["artists"][0]["disambiguation"]
# Out:
# u'90s US grunge band'

# %% [markdown]
# #### Quiz:
#
# When was One Direction Formed?

# %%
oned = query_by_name(ARTIST_URL, query_type["simple"], "One Direction")
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3AOne+Direction&fmt=json

# %%
pretty_print(oned, indent=4)
# Out:
# {
#     "artists": [
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "disambiguation": "English-Irish boy band formed in 2010",
#             "id": "1a425bbd-cca4-4b2c-aeb7-71cb176c828a",
#             "life-span": {
#                 "begin": "2010-07",
#                 "ended": null
#             },
#             "name": "One Direction",
#             "score": "100",
#             "sort-name": "One Direction",
#             "tags": [
#                 {
#                     "count": 2,
#                     "name": "pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "power pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "dance-pop"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "folk pop"
#                 },
#                 {
#                     "count": 2,
#                     "name": "boy band"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "disambiguation": "San Francisco band",
#             "id": "d3479e62-76ac-4aec-9f95-5b222d1e26b1",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction",
#             "score": "69",
#             "sort-name": "Direction",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "b2bc1294-77be-4c7b-af93-9868b83b1f34",
#                 "name": "Auckland",
#                 "sort-name": "Auckland"
#             },
#             "disambiguation": "New Zealand punk?",
#             "id": "a234ebb0-0399-4253-baf6-2ae0abc9d8f2",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction",
#             "score": "47",
#             "sort-name": "Direction"
#         },
#         {
#             "area": {
#                 "id": "ef1b7cc0-cd26-36f4-8ea0-04d9623786c7",
#                 "name": "Netherlands",
#                 "sort-name": "Netherlands"
#             },
#             "begin-area": {
#                 "id": "0b565bc6-05e7-4c3a-bc28-075fabd9a8d0",
#                 "name": "Maastricht",
#                 "sort-name": "Maastricht"
#             },
#             "country": "NL",
#             "id": "574236dc-aa46-4194-8200-6cb039e9ddbd",
#             "life-span": {
#                 "begin": "1989",
#                 "end": "2008",
#                 "ended": true
#             },
#             "name": "Right Direction",
#             "score": "43",
#             "sort-name": "Right Direction",
#             "type": "Group"
#         },
#         {
#             "id": "cfd2b787-3656-44ce-9212-9e555b400af5",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "New Direction",
#             "score": "43",
#             "sort-name": "New Direction"
#         },
#         {
#             "id": "2524b4ea-965f-4628-b940-acd0a9210047",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Lost Direction",
#             "score": "43",
#             "sort-name": "Lost Direction"
#         },
#         {
#             "id": "a32cc520-f2e6-4db2-8b61-c7baca599ef5",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Second Direction",
#             "score": "43",
#             "sort-name": "Second Direction"
#         },
#         {
#             "id": "75fb2c35-4f3a-4145-b948-da871176f039",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Disco Direction",
#             "score": "43",
#             "sort-name": "Disco Direction"
#         },
#         {
#             "id": "9e9d35c3-ce54-4a48-b3ba-4eebdadc1ed8",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Audio Direction",
#             "score": "43",
#             "sort-name": "Audio Direction"
#         },
#         {
#             "id": "355fa6a9-dba2-43b0-bd0f-a9e6dc14c79f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction X",
#             "score": "43",
#             "sort-name": "Direction X",
#             "type": "Group"
#         },
#         {
#             "id": "7c4e4dc0-6a0e-4887-b374-0cc57749f563",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Direction Indicator",
#             "score": "43",
#             "sort-name": "Direction Indicator"
#         },
#         {
#             "id": "74c2fbfc-0ced-4f8a-9da6-7df628755757",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "No Direction",
#             "score": "43",
#             "sort-name": "No Direction",
#             "type": "Group"
#         },
#         {
#             "id": "6130ddae-22dd-4930-ba0f-6d59f81d3637",
#             "life-span": {
#                 "begin": "2009-08",
#                 "ended": null
#             },
#             "name": "The Direction",
#             "score": "43",
#             "sort-name": "Direction, The",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "country": "US",
#             "disambiguation": "USA punk band",
#             "id": "d554887e-2e17-48f4-8610-624a944a9329",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "No Direction",
#             "score": "43",
#             "sort-name": "No Direction",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "punk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "usa"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "id": "ce85410c-10e4-4b2e-a878-72483fcf0884",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "7th Direction",
#             "score": "43",
#             "sort-name": "7th Direction"
#         },
#         {
#             "id": "47813cd0-be78-48ab-802f-1306fc180124",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Loose Direction",
#             "score": "43",
#             "sort-name": "Loose Direction"
#         },
#         {
#             "id": "65cd1bef-0de3-439e-a2fc-a71c308c6359",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "\u9ad8\u67f3\u660c\u884c New Direction",
#             "score": "38",
#             "sort-name": "Masayuki Takayanagi New Direction"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Masayuki \"Jojo\" Takayanagi* & New Direction For The Arts",
#                     "primary": null,
#                     "sort-name": "Masayuki \"Jojo\" Takayanagi* & New Direction For The Arts",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "2db42837-c832-3c27-b4a3-08198f75693c",
#                 "name": "Japan",
#                 "sort-name": "Japan"
#             },
#             "country": "JP",
#             "id": "8367123e-9a2b-4f1a-ad22-52dee85b144a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "New Direction for the Arts",
#             "score": "36",
#             "sort-name": "New Direction for the Arts",
#             "type": "Group"
#         },
#         {
#             "id": "3ccdd708-a6f2-4117-938d-4b23f045cbbb",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The New Transit Direction",
#             "score": "34",
#             "sort-name": "New Transit Direction, The"
#         },
#         {
#             "area": {
#                 "id": "71bbafaa-e825-3e15-8ca9-017dcad1748b",
#                 "name": "Canada",
#                 "sort-name": "Canada"
#             },
#             "country": "CA",
#             "id": "e0027978-441c-4877-b36f-0d2833181a42",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "The Beat Direction",
#             "score": "34",
#             "sort-name": "Beat Direction, The",
#             "type": "Group"
#         },
#         {
#             "disambiguation": "rock",
#             "id": "dffb4132-bfd1-4c23-8128-31c23d0b6fe9",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Found My Direction",
#             "score": "34",
#             "sort-name": "Found My Direction"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "disambiguation": "Hardcore/Gabber DJ Team",
#             "id": "06a2966d-95c1-4e20-a4d6-26e15d1d7e69",
#             "life-span": {
#                 "begin": "2010",
#                 "ended": null
#             },
#             "name": "Tensor & Re-Direction",
#             "score": "34",
#             "sort-name": "Tensor & Re-Direction",
#             "type": "Group"
#         },
#         {
#             "id": "982461f8-d0e0-44c0-9aa3-9ce9df28c71a",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Moving in The Right Direction",
#             "score": "31",
#             "sort-name": "Moving in The Right Direction"
#         },
#         {
#             "disambiguation": "Church choir at Lourdes",
#             "id": "c2485094-3ac9-4632-b8d8-aacae7df3b6f",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Chorale et assembl\u00e9e sous la direction de Jean Zune",
#             "score": "30",
#             "sort-name": "Chorale et assembl\u00e9e sous la direction de Jean Zune"
#         },
#         {
#             "id": "043456b7-0156-4a8d-9591-3018af75ced1",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Orchestre Symphonique National direction Wal-Berg",
#             "score": "28",
#             "sort-name": "Orchestre Symphonique National direction Wal-Berg"
#         }
#     ],
#     "count": 1634,
#     "created": "2016-08-23T13:46:09.669Z",
#     "offset": 0
# }

# %%
oned["artists"][0]["life-span"]["begin"]
# Out:
# u'2010-07'
